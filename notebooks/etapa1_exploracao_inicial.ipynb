# %%
import pandas as pd

# Tentativa 1: Ignorar aspas problemáticas (geralmente resolve esse erro de EOF)
try:
    df = pd.read_csv('Reviews.csv', quoting=3, error_bad_lines=False, engine='python')
    print("Dataset carregado ignorando aspas problemáticas.")
except:
    # Tentativa 2: Caso o erro persista, carregar apenas uma parte para você conseguir os metadados
    df = pd.read_csv('Reviews.csv', nrows=10000)
    print("Dataset carregado parcialmente (primeiras 10k linhas) para análise inicial.")

# 2. Visualizar o Shape
print(f"Dimensões do Dataset: {df.shape[0]} linhas e {df.shape[1]} colunas.\n")

# 3. Visualizar as primeiras 5 linhas
display(df.head())

# 4. Detalhes para Metadados
print("\n--- Informações de Colunas ---")
df.info()
# Out:
# Dataset carregado parcialmente (primeiras 10k linhas) para análise inicial.
# Dimensões do Dataset: 10000 linhas e 10 colunas.
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
# 3                     3                       3      2  1307923200
# 4                     0                       0      5  1350777600
#
# ...
